# %% [markdown]
# <a href="https://colab.research.google.com/github/maryamarshadqaimkhani/Assignment--4/blob/main/04_dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("00_count_nums")

def count_numbers():
    count_dict = {}

    while True:
        user_input = input("Enter a number (or Exit to quit): ")
        if user_input.lower() == 'exit':
            break
        if user_input.isdigit():
            num = int(user_input)
            count_dict[num] = count_dict.get(num, 0) + 1
        else:
            print("Invalid input! Please enter a number or 'Exit'.")

    return count_dict

def display_counts(count_dict):
    print("\nNumber Counts:")
    for key, value in count_dict.items():
        print(f"{key} appears {value} times.")

if __name__ == "__main__":
    count = count_numbers()
    display_counts(count)
# Out:
# 00_count_nums
# Enter a number (or Exit to quit): 3
# Enter a number (or Exit to quit): 4
# Enter a number (or Exit to quit): 3
# Enter a number (or Exit to quit): 6
# Enter a number (or Exit to quit): 4
# Enter a number (or Exit to quit): 3
# Enter a number (or Exit to quit): 12
# Enter a number (or Exit to quit):
# Invalid input! Please enter a number or 'Exit'.
# Enter a number (or Exit to quit): Exit
#
# Number Counts:
# 3 appears 3 times.
# 4 appears 2 times.
# 6 appears 1 times.
# 12 appears 1 times.

# %%
print("01_phonebook")

def add_contact(phonebook):
  name = input("Enter contact name: ")
  number = input("Enter contact number: ")

  if name in phonebook:
    print(f"{name} already exists in phonebook. ")
  else:
    phonebook[name] = number
    print(f"{name} added to the phonebook. ")

def search_contact(phonebook):
  name = input("Enter contact name to search: ")

  if name in phonebook:
    print(f"{name}: {phonebook[name]}")
  else:
    print(f"{name} not found in phonebook. ")

def delete_contact(phonebook):
  name = input("Enter a number to delete: ")

  if name in phonebook:
    del phonebook[name]
    print(f"{name} deleted from the phonebook. ")
  else:
    print(f"{name} not found in phonebook. ")

def display_contact(phonebook):
  if phonebook:
    print("\n Phonebook Contacts List: ")
    for name,number in phonebook.items():
      print(f"{name}: {number}")
  else:
    print("Phonebook is empty. ")

if __name__ == "__main__":
  phonebook = {}

  while True:
    print("\n Phonebook Menu")
    print("1. Add Contact")
    print("2. Search Co3ntact")
    print("3. Delete Contact")
    print("4. Display Contacts")
    print("5. Exit")

    choice = input("Enter your choice(1-5): ")

    if choice == "1":
      add_contact(phonebook)
    elif choice == "2":
      search_contact(phonebook)
    elif choice == "3":
      delete_contact(phonebook)
    elif choice == "4":
      display_contact(phonebook)
    elif choice == "5":
      print("Exiting Phonebook. Goodbye!")
      break
    else:
      print("Invalid choice. Please enter a number between 1 to 5. ")
# Out:
# 01_phonebook
#
#  Phonebook Menu
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Contacts
# 5. Exit
# Enter your choice(1-5): 1
# Enter contact name: mama
# Enter contact number: 03224652157
# mama added to the phonebook.
#
#  Phonebook Menu
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Contacts
# 5. Exit
# Enter your choice(1-5): 2
# Enter contact name to search: baba
# baba not found in phonebook.
#
#  Phonebook Menu
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Contacts
# 5. Exit
# Enter your choice(1-5): 2
# Enter contact name to search: mama
# mama: 03224652157
#
#  Phonebook Menu
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Contacts
# 5. Exit
# Enter your choice(1-5): 4
#
#  Phonebook Contacts List:
# mama: 03224652157
#
#  Phonebook Menu
# 1. Add Contact
# 2. Search Contact
# 3. Delete Contact
# 4. Display Contacts
# 5. Exit
# Enter your choice(1-5): 1
# Enter contact name: baba
# ...

# %%
print("02_pop_up_shop")

def calculate_total_cost():
  fruits_price = {
      "apple":5.0,
      "mango":15.0,
      "kiwi":8.0,
      "pear":12.0,
      "banana":6.0,
      "orange":10.0
  }

  total_cost = 0

  for fruit, price in fruits_price.items():
    while True:
      try:
        quantity = int(input(f"How many {fruit} do you want?: "))
        if quantity < 0:
          print("Invalid input. Please enter a non-negative number. ")
          continue
        total_cost += price * quantity
        break
      except ValueError:
        print("Invalid input. Please enter a valid number.")
        continue

    print(f"\n Your total cost is: ${total_cost:.2f}")

if __name__ == "__main__":
  calculate_total_cost()
# Out:
# 02_pop_up_shop
# How many apple do you want?: 5
#
#  Your total cost is: $25.00
# How many mango do you want?: 10
#
#  Your total cost is: $175.00
# How many kiwi do you want?: 20
#
#  Your total cost is: $335.00
# How many pear do you want?: 60
#
#  Your total cost is: $1055.00
# How many banana do you want?: 620
#
#  Your total cost is: $4775.00
# How many orange do you want?: 2633.
# Invalid input. Please enter a valid number.
# How many orange do you want?: 2633
#
#  Your total cost is: $31105.00

# %%
import hashlib

print("03_powerful_passwords")

def hash_password(password):
  return hashlib.sha256(password.encode()).hexdigest()

stored_logins = {
    "user@example.com":hash_password("password123"),
    "admin@example.com":hash_password("adminpass")
}

def login(email,password):
  if email in stored_logins:
    return stored_logins[email] == hash_password(password)
  return False


if __name__ == '__main__':
  email = input("Enter your email: ")
  password = input("Enter your password: ")

  if login(email,password):
    print("Login Successfull. ")
  else:
    print("Invalid email and passsword. ")
# Out:
# 03_powerful_passwords
# Enter your email: user@example.com
# Enter your password: password123
# Login Successfull.
